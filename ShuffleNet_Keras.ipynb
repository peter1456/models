# %% [markdown]
# <a href="https://colab.research.google.com/github/GraWick/Deep-Learning-Project/blob/version-felippe/ShuffleNet_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model
from keras.layers import *
from keras.activations import *
from keras.callbacks import *
import keras.backend as K


def _stage(tensor, nb_groups, in_channels, out_channels, repeat):
    x = _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, 2)

    for _ in range(repeat):
        x = _shufflenet_unit(x, nb_groups, out_channels, out_channels, 1)

    return x


def _pw_group(tensor, nb_groups, in_channels, out_channels):
    """Pointwise grouped convolution."""
    nb_chan_per_grp = in_channels // nb_groups

    pw_convs = []
    for grp in range(nb_groups):
        x = Lambda(lambda x: x[:, :, :, nb_chan_per_grp * grp: nb_chan_per_grp * (grp + 1)])(tensor)
        grp_out_chan = int(out_channels / nb_groups + 0.5)

        pw_convs.append(
            Conv2D(grp_out_chan,
                   kernel_size=(1, 1),
                   padding='same',
                   use_bias=False,
                   strides=1)(x)
        )

    return Concatenate(axis=-1)(pw_convs)


def _shuffle(x, nb_groups):
    def shuffle_layer(x):
        _, w, h, n = K.int_shape(x)
        nb_chan_per_grp = n // nb_groups

        x = K.reshape(x, (-1, w, h, nb_chan_per_grp, nb_groups))
        x = K.permute_dimensions(x, (0, 1, 2, 4, 3)) # Transpose only grps and chs
        x = K.reshape(x, (-1, w, h, n))

        return x

    return Lambda(shuffle_layer)(x)


def _shufflenet_unit(tensor, nb_groups, in_channels, out_channels, strides, shuffle=True, bottleneck=4):
    bottleneck_channels = out_channels // bottleneck

    x = _pw_group(tensor, nb_groups, in_channels, bottleneck_channels)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    if shuffle:
        x = _shuffle(x, nb_groups)

    x = DepthwiseConv2D(kernel_size=(3, 3),
                        padding='same',
                        use_bias=False,
                        strides=strides)(x)
    x = BatchNormalization()(x)


    x = _pw_group(x, nb_groups, bottleneck_channels,
                  out_channels if strides < 2 else out_channels - in_channels)
    x = BatchNormalization()(x)

    if strides < 2:
        x = Add()([tensor, x])
    else:
        avg = AveragePooling2D(pool_size=(3, 3),
                               strides=2,
                               padding='same')(tensor)

        x = Concatenate(axis=-1)([avg, x])

    x = Activation('relu')(x)

    return x


def _info(nb_groups):
    return {
        1: [24, 144, 288, 576],
        2: [24, 200, 400, 800],
        3: [24, 240, 480, 960],
        4: [24, 272, 544, 1088],
        8: [24, 384, 768, 1536]
    }[nb_groups], [None, 3, 7, 3]


def ShuffleNet(input_shape, nb_classes, include_top=True, weights=None, nb_groups=8):
    x_in = Input(shape=input_shape)

    x = Conv2D(24,
               kernel_size=(3, 3),
               strides=2,
               use_bias=False,
               padding='same')(x_in)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = MaxPooling2D(pool_size=(3, 3),
                     strides=2,
                     padding='same')(x)

    channels_list, repeat_list = _info(nb_groups)
    for i, (out_channels, repeat) in enumerate(zip(channels_list[1:], repeat_list[1:]), start=1):
        x = _stage(x, nb_groups, channels_list[i-1], out_channels, repeat)

    if include_top:
        x = GlobalAveragePooling2D()(x)
        x = Dense(nb_classes, activation='softmax')(x)

    model = Model(inputs=x_in, outputs=x)

    if weights is not None:
        model.load_weights(weights, by_name=True)

    return model

# %%
from keras.datasets import cifar10
(x_train, y_train_), (x_test, y_test_) = cifar10.load_data()

'''# Load a given dataset by name, along with the DatasetInfo
import tensorflow_datasets as tfds

data, info = tfds.load("cifar10", with_info=True)
train_data, test_data = data['train'], data['test']'''

# TODO load from drive 

# Rescaling of the pixel values from 0 to 255 to the range between 0 and 1. It improves the learning speed.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_train.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 26s 0us/step
# (50000, 32, 32, 3)

# %%
# one-hot encoding of labels
num_classes = 10;
def one_hot(a, num_classes):
  return np.squeeze(np.eye(num_classes)[a.reshape(-1)])

y_train = one_hot(y_train_, num_classes)
y_test = one_hot(y_test_, num_classes)

'''# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
'''
# Out:
# '# convert class vectors to binary class matrices\ny_train = keras.utils.to_categorical(y_train, 10)\ny_test = keras.utils.to_categorical(y_test, 10)\n'

# %%
########################################
# execute the model
########################################
import keras
n_epochs = 50
batch_size = 256
input_shape = [32, 32, 3]
nb_classes = 10


model = ShuffleNet(input_shape, nb_classes, include_top=True, weights=None, nb_groups=8)
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=batch_size, epochs=n_epochs, verbose=1, validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 67s 1ms/step - loss: 2.1449 - acc: 0.3150 - val_loss: 3.0268 - val_acc: 0.2951
# Epoch 2/50
# 50000/50000 [==============================] - 29s 577us/step - loss: 1.6397 - acc: 0.4323 - val_loss: 1.9048 - val_acc: 0.4010
# Epoch 3/50
# 50000/50000 [==============================] - 29s 581us/step - loss: 1.4475 - acc: 0.4956 - val_loss: 1.6184 - val_acc: 0.4491
# Epoch 4/50
# 50000/50000 [==============================] - 29s 583us/step - loss: 1.2960 - acc: 0.5421 - val_loss: 1.6472 - val_acc: 0.4729
# Epoch 5/50
# 50000/50000 [==============================] - 29s 572us/step - loss: 1.1920 - acc: 0.5801 - val_loss: 1.6913 - val_acc: 0.4709
# Epoch 6/50
# 50000/50000 [==============================] - 29s 588us/step - loss: 1.1008 - acc: 0.6135 - val_loss: 1.6620 - val_acc: 0.4815
# Epoch 7/50
# 50000/50000 [==============================] - 28s 568us/step - loss: 1.0617 - acc: 0.6269 - val_loss: 1.6389 - val_acc: 0.4811
# Epoch 8/50
# 50000/50000 [==============================] - 28s 567us/step - loss: 0.9847 - acc: 0.6512 - val_loss: 1.5132 - val_acc: 0.5278
# Epoch 9/50
# 50000/50000 [==============================] - 29s 585us/step - loss: 0.9139 - acc: 0.6758 - val_loss: 1.7663 - val_acc: 0.4873
# Epoch 10/50
# 50000/50000 [==============================] - 28s 569us/step - loss: 0.8837 - acc: 0.6888 - val_loss: 1.8094 - val_acc: 0.4847
# Epoch 11/50
# 50000/50000 [==============================] - 29s 586us/step - loss: 0.8408 - acc: 0.7015 - val_loss: 1.6942 - val_acc: 0.5196
# Epoch 12/50
# 50000/50000 [==============================] - 29s 582us/step - loss: 0.7683 - acc: 0.7253 - val_loss: 1.8736 - val_acc: 0.4779
# Epoch 13/50
# 50000/50000 [==============================] - 28s 562us/step - loss: 0.7356 - acc: 0.7370 - val_loss: 1.8454 - val_acc: 0.4914
# Epoch 14/50
# 50000/50000 [==============================] - 29s 575us/step - loss: 0.6866 - acc: 0.7568 - val_loss: 1.7653 - val_acc: 0.5224
# Epoch 15/50
# 50000/50000 [==============================] - 29s 582us/step - loss: 0.6435 - acc: 0.7712 - val_loss: 1.8508 - val_acc: 0.5156
# Epoch 16/50
# 50000/50000 [==============================] - 28s 563us/step - loss: 0.6142 - acc: 0.7804 - val_loss: 1.8061 - val_acc: 0.5299
# Epoch 17/50
# 50000/50000 [==============================] - 29s 571us/step - loss: 0.5913 - acc: 0.7894 - val_loss: 1.9285 - val_acc: 0.5233
# Epoch 18/50
# 50000/50000 [==============================] - 29s 573us/step - loss: 0.5435 - acc: 0.8053 - val_loss: 1.8837 - val_acc: 0.5397
# Epoch 19/50
# 50000/50000 [==============================] - 28s 566us/step - loss: 0.5108 - acc: 0.8174 - val_loss: 2.3496 - val_acc: 0.4845
# Epoch 20/50
# 50000/50000 [==============================] - 29s 580us/step - loss: 0.4947 - acc: 0.8245 - val_loss: 1.9847 - val_acc: 0.5360
# Epoch 21/50
# 50000/50000 [==============================] - 28s 561us/step - loss: 0.4720 - acc: 0.8338 - val_loss: 2.2924 - val_acc: 0.5114
# Epoch 22/50
# 50000/50000 [==============================] - 29s 590us/step - loss: 0.4281 - acc: 0.8504 - val_loss: 1.9197 - val_acc: 0.5497
# Epoch 23/50
# 50000/50000 [==============================] - 29s 582us/step - loss: 0.3812 - acc: 0.8633 - val_loss: 2.2286 - val_acc: 0.5288
# Epoch 24/50
# 50000/50000 [==============================] - 28s 560us/step - loss: 0.3818 - acc: 0.8637 - val_loss: 2.0949 - val_acc: 0.5507
# Epoch 25/50
# 50000/50000 [==============================] - 29s 574us/step - loss: 0.3441 - acc: 0.8769 - val_loss: 2.0931 - val_acc: 0.5438
# Epoch 26/50
# 50000/50000 [==============================] - 29s 582us/step - loss: 0.3491 - acc: 0.8760 - val_loss: 2.1847 - val_acc: 0.5383
# Epoch 27/50
# 50000/50000 [==============================] - 28s 564us/step - loss: 0.3031 - acc: 0.8908 - val_loss: 2.3977 - val_acc: 0.5338
# Epoch 28/50
# 50000/50000 [==============================] - 28s 564us/step - loss: 0.2977 - acc: 0.8929 - val_loss: 2.2967 - val_acc: 0.5340
# Epoch 29/50
# 50000/50000 [==============================] - 29s 572us/step - loss: 0.3013 - acc: 0.8924 - val_loss: 2.2623 - val_acc: 0.5571
# Epoch 30/50
# 50000/50000 [==============================] - 27s 549us/step - loss: 0.2982 - acc: 0.8973 - val_loss: 2.2450 - val_acc: 0.5621
# Epoch 31/50
# 50000/50000 [==============================] - 28s 553us/step - loss: 0.2794 - acc: 0.9011 - val_loss: 2.2261 - val_acc: 0.5509
# Epoch 32/50
# 50000/50000 [==============================] - 28s 562us/step - loss: 0.2534 - acc: 0.9104 - val_loss: 2.3187 - val_acc: 0.5666
# Epoch 33/50
# 50000/50000 [==============================] - 29s 573us/step - loss: 0.2398 - acc: 0.9140 - val_loss: 2.2492 - val_acc: 0.5726
# Epoch 34/50
# 50000/50000 [==============================] - 30s 608us/step - loss: 0.2509 - acc: 0.9122 - val_loss: 2.2896 - val_acc: 0.5534
# Epoch 35/50
# 50000/50000 [==============================] - 29s 572us/step - loss: 0.2245 - acc: 0.9207 - val_loss: 2.3858 - val_acc: 0.5567
# Epoch 36/50
# 50000/50000 [==============================] - 28s 561us/step - loss: 0.2422 - acc: 0.9162 - val_loss: 2.3384 - val_acc: 0.5659
# Epoch 37/50
# 50000/50000 [==============================] - 29s 577us/step - loss: 0.2212 - acc: 0.9220 - val_loss: 2.4723 - val_acc: 0.5490
# Epoch 38/50
# 50000/50000 [==============================] - 28s 557us/step - loss: 0.1919 - acc: 0.9326 - val_loss: 2.3560 - val_acc: 0.5603
# Epoch 39/50
# 50000/50000 [==============================] - 28s 561us/step - loss: 0.1878 - acc: 0.9333 - val_loss: 2.4558 - val_acc: 0.5735
# Epoch 40/50
# 50000/50000 [==============================] - 29s 577us/step - loss: 0.2055 - acc: 0.9277 - val_loss: 2.6245 - val_acc: 0.5472
# Epoch 41/50
# 50000/50000 [==============================] - 28s 558us/step - loss: 0.1849 - acc: 0.9349 - val_loss: 2.6571 - val_acc: 0.5500
# Epoch 42/50
# 50000/50000 [==============================] - 28s 555us/step - loss: 0.1982 - acc: 0.9308 - val_loss: 2.2160 - val_acc: 0.5797
# Epoch 43/50
# 50000/50000 [==============================] - 29s 576us/step - loss: 0.1673 - acc: 0.9411 - val_loss: 2.3747 - val_acc: 0.5751
# Epoch 44/50
# 50000/50000 [==============================] - 29s 586us/step - loss: 0.1583 - acc: 0.9446 - val_loss: 2.4917 - val_acc: 0.5577
# Epoch 45/50
# 50000/50000 [==============================] - 28s 558us/step - loss: 0.2122 - acc: 0.9282 - val_loss: 2.5892 - val_acc: 0.5630
# Epoch 46/50
# 50000/50000 [==============================] - 29s 589us/step - loss: 0.2016 - acc: 0.9302 - val_loss: 2.3992 - val_acc: 0.5757
# Epoch 47/50
# 50000/50000 [==============================] - 28s 559us/step - loss: 0.1723 - acc: 0.9408 - val_loss: 2.5379 - val_acc: 0.5644
# Epoch 48/50
# 50000/50000 [==============================] - 28s 565us/step - loss: 0.1938 - acc: 0.9335 - val_loss: 2.5599 - val_acc: 0.5511
# Epoch 49/50
# 50000/50000 [==============================] - 28s 570us/step - loss: 0.1894 - acc: 0.9335 - val_loss: 2.4954 - val_acc: 0.5740
# Epoch 50/50
# 50000/50000 [==============================] - 28s 559us/step - loss: 0.1486 - acc: 0.9487 - val_loss: 2.2915 - val_acc: 0.5953
# Test loss: 2.2915456790924074
# Test accuracy: 0.5953

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_772 (Conv2D)             (None, 16, 16, 24)   648         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 16, 16, 24)   96          conv2d_772[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 16, 16, 24)   0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 24)     0           activation_100[0][0]
# __________________________________________________________________________________________________
# lambda_817 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_818 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_819 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_820 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_821 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_822 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_823 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_824 (Lambda)             (None, 8, 8, 3)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_773 (Conv2D)             (None, 8, 8, 12)     36          lambda_817[0][0]
# __________________________________________________________________________________________________
# conv2d_774 (Conv2D)             (None, 8, 8, 12)     36          lambda_818[0][0]
# __________________________________________________________________________________________________
# conv2d_775 (Conv2D)             (None, 8, 8, 12)     36          lambda_819[0][0]
# __________________________________________________________________________________________________
# conv2d_776 (Conv2D)             (None, 8, 8, 12)     36          lambda_820[0][0]
# __________________________________________________________________________________________________
# conv2d_777 (Conv2D)             (None, 8, 8, 12)     36          lambda_821[0][0]
# __________________________________________________________________________________________________
# conv2d_778 (Conv2D)             (None, 8, 8, 12)     36          lambda_822[0][0]
# __________________________________________________________________________________________________
# conv2d_779 (Conv2D)             (None, 8, 8, 12)     36          lambda_823[0][0]
# __________________________________________________________________________________________________
# conv2d_780 (Conv2D)             (None, 8, 8, 12)     36          lambda_824[0][0]
# __________________________________________________________________________________________________
# concatenate_106 (Concatenate)   (None, 8, 8, 96)     0           conv2d_773[0][0]
#                                                                  conv2d_774[0][0]
#                                                                  conv2d_775[0][0]
#                                                                  conv2d_776[0][0]
#                                                                  conv2d_777[0][0]
#                                                                  conv2d_778[0][0]
#                                                                  conv2d_779[0][0]
#                                                                  conv2d_780[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 8, 8, 96)     384         concatenate_106[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 8, 8, 96)     0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# lambda_825 (Lambda)             (None, 8, 8, 96)     0           activation_101[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_49 (DepthwiseC (None, 4, 4, 96)     864         lambda_825[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 4, 4, 96)     384         depthwise_conv2d_49[0][0]
# __________________________________________________________________________________________________
# lambda_826 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_827 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_828 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_829 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_830 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_831 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_832 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# lambda_833 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_781 (Conv2D)             (None, 4, 4, 45)     540         lambda_826[0][0]
# __________________________________________________________________________________________________
# conv2d_782 (Conv2D)             (None, 4, 4, 45)     540         lambda_827[0][0]
# __________________________________________________________________________________________________
# conv2d_783 (Conv2D)             (None, 4, 4, 45)     540         lambda_828[0][0]
# __________________________________________________________________________________________________
# conv2d_784 (Conv2D)             (None, 4, 4, 45)     540         lambda_829[0][0]
# __________________________________________________________________________________________________
# conv2d_785 (Conv2D)             (None, 4, 4, 45)     540         lambda_830[0][0]
# __________________________________________________________________________________________________
# conv2d_786 (Conv2D)             (None, 4, 4, 45)     540         lambda_831[0][0]
# __________________________________________________________________________________________________
# conv2d_787 (Conv2D)             (None, 4, 4, 45)     540         lambda_832[0][0]
# __________________________________________________________________________________________________
# conv2d_788 (Conv2D)             (None, 4, 4, 45)     540         lambda_833[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 4, 4, 360)    0           conv2d_781[0][0]
#                                                                  conv2d_782[0][0]
#                                                                  conv2d_783[0][0]
#                                                                  conv2d_784[0][0]
#                                                                  conv2d_785[0][0]
#                                                                  conv2d_786[0][0]
#                                                                  conv2d_787[0][0]
#                                                                  conv2d_788[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 4, 4, 24)     0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 4, 4, 360)    1440        concatenate_107[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, 4, 4, 384)    0           average_pooling2d_10[0][0]
#                                                                  batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 4, 4, 384)    0           concatenate_108[0][0]
# __________________________________________________________________________________________________
# lambda_834 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_835 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_836 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_837 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_838 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_839 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_840 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# lambda_841 (Lambda)             (None, 4, 4, 48)     0           activation_102[0][0]
# __________________________________________________________________________________________________
# conv2d_789 (Conv2D)             (None, 4, 4, 12)     576         lambda_834[0][0]
# __________________________________________________________________________________________________
# conv2d_790 (Conv2D)             (None, 4, 4, 12)     576         lambda_835[0][0]
# __________________________________________________________________________________________________
# conv2d_791 (Conv2D)             (None, 4, 4, 12)     576         lambda_836[0][0]
# __________________________________________________________________________________________________
# conv2d_792 (Conv2D)             (None, 4, 4, 12)     576         lambda_837[0][0]
# __________________________________________________________________________________________________
# conv2d_793 (Conv2D)             (None, 4, 4, 12)     576         lambda_838[0][0]
# __________________________________________________________________________________________________
# conv2d_794 (Conv2D)             (None, 4, 4, 12)     576         lambda_839[0][0]
# __________________________________________________________________________________________________
# conv2d_795 (Conv2D)             (None, 4, 4, 12)     576         lambda_840[0][0]
# __________________________________________________________________________________________________
# conv2d_796 (Conv2D)             (None, 4, 4, 12)     576         lambda_841[0][0]
# __________________________________________________________________________________________________
# concatenate_109 (Concatenate)   (None, 4, 4, 96)     0           conv2d_789[0][0]
#                                                                  conv2d_790[0][0]
#                                                                  conv2d_791[0][0]
#                                                                  conv2d_792[0][0]
#                                                                  conv2d_793[0][0]
#                                                                  conv2d_794[0][0]
#                                                                  conv2d_795[0][0]
#                                                                  conv2d_796[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 4, 4, 96)     384         concatenate_109[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 4, 4, 96)     0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# lambda_842 (Lambda)             (None, 4, 4, 96)     0           activation_103[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_50 (DepthwiseC (None, 4, 4, 96)     864         lambda_842[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 4, 4, 96)     384         depthwise_conv2d_50[0][0]
# __________________________________________________________________________________________________
# lambda_843 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_844 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_845 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_846 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_847 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_848 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_849 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# lambda_850 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_797 (Conv2D)             (None, 4, 4, 48)     576         lambda_843[0][0]
# __________________________________________________________________________________________________
# conv2d_798 (Conv2D)             (None, 4, 4, 48)     576         lambda_844[0][0]
# __________________________________________________________________________________________________
# conv2d_799 (Conv2D)             (None, 4, 4, 48)     576         lambda_845[0][0]
# __________________________________________________________________________________________________
# conv2d_800 (Conv2D)             (None, 4, 4, 48)     576         lambda_846[0][0]
# __________________________________________________________________________________________________
# conv2d_801 (Conv2D)             (None, 4, 4, 48)     576         lambda_847[0][0]
# __________________________________________________________________________________________________
# conv2d_802 (Conv2D)             (None, 4, 4, 48)     576         lambda_848[0][0]
# __________________________________________________________________________________________________
# conv2d_803 (Conv2D)             (None, 4, 4, 48)     576         lambda_849[0][0]
# __________________________________________________________________________________________________
# conv2d_804 (Conv2D)             (None, 4, 4, 48)     576         lambda_850[0][0]
# __________________________________________________________________________________________________
# concatenate_110 (Concatenate)   (None, 4, 4, 384)    0           conv2d_797[0][0]
#                                                                  conv2d_798[0][0]
#                                                                  conv2d_799[0][0]
#                                                                  conv2d_800[0][0]
#                                                                  conv2d_801[0][0]
#                                                                  conv2d_802[0][0]
#                                                                  conv2d_803[0][0]
#                                                                  conv2d_804[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 4, 4, 384)    1536        concatenate_110[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 4, 4, 384)    0           activation_102[0][0]
#                                                                  batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 4, 4, 384)    0           add_40[0][0]
# __________________________________________________________________________________________________
# lambda_851 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_852 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_853 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_854 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_855 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_856 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_857 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# lambda_858 (Lambda)             (None, 4, 4, 48)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_805 (Conv2D)             (None, 4, 4, 12)     576         lambda_851[0][0]
# __________________________________________________________________________________________________
# conv2d_806 (Conv2D)             (None, 4, 4, 12)     576         lambda_852[0][0]
# __________________________________________________________________________________________________
# conv2d_807 (Conv2D)             (None, 4, 4, 12)     576         lambda_853[0][0]
# __________________________________________________________________________________________________
# conv2d_808 (Conv2D)             (None, 4, 4, 12)     576         lambda_854[0][0]
# __________________________________________________________________________________________________
# conv2d_809 (Conv2D)             (None, 4, 4, 12)     576         lambda_855[0][0]
# __________________________________________________________________________________________________
# conv2d_810 (Conv2D)             (None, 4, 4, 12)     576         lambda_856[0][0]
# __________________________________________________________________________________________________
# conv2d_811 (Conv2D)             (None, 4, 4, 12)     576         lambda_857[0][0]
# __________________________________________________________________________________________________
# conv2d_812 (Conv2D)             (None, 4, 4, 12)     576         lambda_858[0][0]
# __________________________________________________________________________________________________
# concatenate_111 (Concatenate)   (None, 4, 4, 96)     0           conv2d_805[0][0]
#                                                                  conv2d_806[0][0]
#                                                                  conv2d_807[0][0]
#                                                                  conv2d_808[0][0]
#                                                                  conv2d_809[0][0]
#                                                                  conv2d_810[0][0]
#                                                                  conv2d_811[0][0]
#                                                                  conv2d_812[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 4, 4, 96)     384         concatenate_111[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 4, 4, 96)     0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# lambda_859 (Lambda)             (None, 4, 4, 96)     0           activation_105[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_51 (DepthwiseC (None, 4, 4, 96)     864         lambda_859[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 4, 4, 96)     384         depthwise_conv2d_51[0][0]
# __________________________________________________________________________________________________
# lambda_860 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_861 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_862 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_863 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_864 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_865 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_866 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# lambda_867 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_813 (Conv2D)             (None, 4, 4, 48)     576         lambda_860[0][0]
# __________________________________________________________________________________________________
# conv2d_814 (Conv2D)             (None, 4, 4, 48)     576         lambda_861[0][0]
# __________________________________________________________________________________________________
# conv2d_815 (Conv2D)             (None, 4, 4, 48)     576         lambda_862[0][0]
# __________________________________________________________________________________________________
# conv2d_816 (Conv2D)             (None, 4, 4, 48)     576         lambda_863[0][0]
# __________________________________________________________________________________________________
# conv2d_817 (Conv2D)             (None, 4, 4, 48)     576         lambda_864[0][0]
# __________________________________________________________________________________________________
# conv2d_818 (Conv2D)             (None, 4, 4, 48)     576         lambda_865[0][0]
# __________________________________________________________________________________________________
# conv2d_819 (Conv2D)             (None, 4, 4, 48)     576         lambda_866[0][0]
# __________________________________________________________________________________________________
# conv2d_820 (Conv2D)             (None, 4, 4, 48)     576         lambda_867[0][0]
# __________________________________________________________________________________________________
# concatenate_112 (Concatenate)   (None, 4, 4, 384)    0           conv2d_813[0][0]
#                                                                  conv2d_814[0][0]
#                                                                  conv2d_815[0][0]
#                                                                  conv2d_816[0][0]
#                                                                  conv2d_817[0][0]
#                                                                  conv2d_818[0][0]
#                                                                  conv2d_819[0][0]
#                                                                  conv2d_820[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 4, 4, 384)    1536        concatenate_112[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 4, 4, 384)    0           activation_104[0][0]
#                                                                  batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 4, 4, 384)    0           add_41[0][0]
# __________________________________________________________________________________________________
# lambda_868 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_869 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_870 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_871 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_872 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_873 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_874 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# lambda_875 (Lambda)             (None, 4, 4, 48)     0           activation_106[0][0]
# __________________________________________________________________________________________________
# conv2d_821 (Conv2D)             (None, 4, 4, 12)     576         lambda_868[0][0]
# __________________________________________________________________________________________________
# conv2d_822 (Conv2D)             (None, 4, 4, 12)     576         lambda_869[0][0]
# __________________________________________________________________________________________________
# conv2d_823 (Conv2D)             (None, 4, 4, 12)     576         lambda_870[0][0]
# __________________________________________________________________________________________________
# conv2d_824 (Conv2D)             (None, 4, 4, 12)     576         lambda_871[0][0]
# __________________________________________________________________________________________________
# conv2d_825 (Conv2D)             (None, 4, 4, 12)     576         lambda_872[0][0]
# __________________________________________________________________________________________________
# conv2d_826 (Conv2D)             (None, 4, 4, 12)     576         lambda_873[0][0]
# __________________________________________________________________________________________________
# conv2d_827 (Conv2D)             (None, 4, 4, 12)     576         lambda_874[0][0]
# __________________________________________________________________________________________________
# conv2d_828 (Conv2D)             (None, 4, 4, 12)     576         lambda_875[0][0]
# __________________________________________________________________________________________________
# concatenate_113 (Concatenate)   (None, 4, 4, 96)     0           conv2d_821[0][0]
#                                                                  conv2d_822[0][0]
#                                                                  conv2d_823[0][0]
#                                                                  conv2d_824[0][0]
#                                                                  conv2d_825[0][0]
#                                                                  conv2d_826[0][0]
#                                                                  conv2d_827[0][0]
#                                                                  conv2d_828[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 4, 4, 96)     384         concatenate_113[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 4, 4, 96)     0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# lambda_876 (Lambda)             (None, 4, 4, 96)     0           activation_107[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_52 (DepthwiseC (None, 4, 4, 96)     864         lambda_876[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 4, 4, 96)     384         depthwise_conv2d_52[0][0]
# __________________________________________________________________________________________________
# lambda_877 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_878 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_879 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_880 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_881 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_882 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_883 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# lambda_884 (Lambda)             (None, 4, 4, 12)     0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_829 (Conv2D)             (None, 4, 4, 48)     576         lambda_877[0][0]
# __________________________________________________________________________________________________
# conv2d_830 (Conv2D)             (None, 4, 4, 48)     576         lambda_878[0][0]
# __________________________________________________________________________________________________
# conv2d_831 (Conv2D)             (None, 4, 4, 48)     576         lambda_879[0][0]
# __________________________________________________________________________________________________
# conv2d_832 (Conv2D)             (None, 4, 4, 48)     576         lambda_880[0][0]
# __________________________________________________________________________________________________
# conv2d_833 (Conv2D)             (None, 4, 4, 48)     576         lambda_881[0][0]
# __________________________________________________________________________________________________
# conv2d_834 (Conv2D)             (None, 4, 4, 48)     576         lambda_882[0][0]
# __________________________________________________________________________________________________
# conv2d_835 (Conv2D)             (None, 4, 4, 48)     576         lambda_883[0][0]
# __________________________________________________________________________________________________
# conv2d_836 (Conv2D)             (None, 4, 4, 48)     576         lambda_884[0][0]
# __________________________________________________________________________________________________
# concatenate_114 (Concatenate)   (None, 4, 4, 384)    0           conv2d_829[0][0]
#                                                                  conv2d_830[0][0]
#                                                                  conv2d_831[0][0]
#                                                                  conv2d_832[0][0]
#                                                                  conv2d_833[0][0]
#                                                                  conv2d_834[0][0]
#                                                                  conv2d_835[0][0]
#                                                                  conv2d_836[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 4, 4, 384)    1536        concatenate_114[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 4, 4, 384)    0           activation_106[0][0]
#                                                                  batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 4, 4, 384)    0           add_42[0][0]
# __________________________________________________________________________________________________
# lambda_885 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_886 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_887 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_888 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_889 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_890 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_891 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# lambda_892 (Lambda)             (None, 4, 4, 48)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_837 (Conv2D)             (None, 4, 4, 24)     1152        lambda_885[0][0]
# __________________________________________________________________________________________________
# conv2d_838 (Conv2D)             (None, 4, 4, 24)     1152        lambda_886[0][0]
# __________________________________________________________________________________________________
# conv2d_839 (Conv2D)             (None, 4, 4, 24)     1152        lambda_887[0][0]
# __________________________________________________________________________________________________
# conv2d_840 (Conv2D)             (None, 4, 4, 24)     1152        lambda_888[0][0]
# __________________________________________________________________________________________________
# conv2d_841 (Conv2D)             (None, 4, 4, 24)     1152        lambda_889[0][0]
# __________________________________________________________________________________________________
# conv2d_842 (Conv2D)             (None, 4, 4, 24)     1152        lambda_890[0][0]
# __________________________________________________________________________________________________
# conv2d_843 (Conv2D)             (None, 4, 4, 24)     1152        lambda_891[0][0]
# __________________________________________________________________________________________________
# conv2d_844 (Conv2D)             (None, 4, 4, 24)     1152        lambda_892[0][0]
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, 4, 4, 192)    0           conv2d_837[0][0]
#                                                                  conv2d_838[0][0]
#                                                                  conv2d_839[0][0]
#                                                                  conv2d_840[0][0]
#                                                                  conv2d_841[0][0]
#                                                                  conv2d_842[0][0]
#                                                                  conv2d_843[0][0]
#                                                                  conv2d_844[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 4, 4, 192)    768         concatenate_115[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 4, 4, 192)    0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# lambda_893 (Lambda)             (None, 4, 4, 192)    0           activation_109[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_53 (DepthwiseC (None, 2, 2, 192)    1728        lambda_893[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 2, 2, 192)    768         depthwise_conv2d_53[0][0]
# __________________________________________________________________________________________________
# lambda_894 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_895 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_896 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_897 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_898 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_899 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_900 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# lambda_901 (Lambda)             (None, 2, 2, 24)     0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_845 (Conv2D)             (None, 2, 2, 48)     1152        lambda_894[0][0]
# __________________________________________________________________________________________________
# conv2d_846 (Conv2D)             (None, 2, 2, 48)     1152        lambda_895[0][0]
# __________________________________________________________________________________________________
# conv2d_847 (Conv2D)             (None, 2, 2, 48)     1152        lambda_896[0][0]
# __________________________________________________________________________________________________
# ...
# activation_129 (Activation)     (None, 1, 1, 384)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# lambda_1063 (Lambda)            (None, 1, 1, 384)    0           activation_129[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_63 (DepthwiseC (None, 1, 1, 384)    3456        lambda_1063[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 1, 1, 384)    1536        depthwise_conv2d_63[0][0]
# __________________________________________________________________________________________________
# lambda_1064 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1065 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1066 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1067 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1068 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1069 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1070 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# lambda_1071 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_1005 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# conv2d_1006 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# conv2d_1007 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# conv2d_1008 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# conv2d_1009 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1010 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# conv2d_1011 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# conv2d_1012 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# concatenate_138 (Concatenate)   (None, 1, 1, 1536)   0           conv2d_1005[0][0]
#                                                                  conv2d_1006[0][0]
#                                                                  conv2d_1007[0][0]
#                                                                  conv2d_1008[0][0]
#                                                                  conv2d_1009[0][0]
#                                                                  conv2d_1010[0][0]
#                                                                  conv2d_1011[0][0]
#                                                                  conv2d_1012[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 1, 1, 1536)   6144        concatenate_138[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 1, 1, 1536)   0           activation_128[0][0]
#                                                                  batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 1, 1, 1536)   0           add_51[0][0]
# __________________________________________________________________________________________________
# lambda_1072 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1073 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1074 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1075 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1076 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1077 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1078 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 1, 1, 192)    0           activation_130[0][0]
# __________________________________________________________________________________________________
# conv2d_1013 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# conv2d_1014 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# conv2d_1015 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# conv2d_1016 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1017 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1018 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# conv2d_1019 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# conv2d_1020 (Conv2D)            (None, 1, 1, 48)     9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# concatenate_139 (Concatenate)   (None, 1, 1, 384)    0           conv2d_1013[0][0]
#                                                                  conv2d_1014[0][0]
#                                                                  conv2d_1015[0][0]
#                                                                  conv2d_1016[0][0]
#                                                                  conv2d_1017[0][0]
#                                                                  conv2d_1018[0][0]
#                                                                  conv2d_1019[0][0]
#                                                                  conv2d_1020[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 1, 1, 384)    1536        concatenate_139[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 1, 1, 384)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 1, 1, 384)    0           activation_131[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_64 (DepthwiseC (None, 1, 1, 384)    3456        lambda_1080[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 1, 1, 384)    1536        depthwise_conv2d_64[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 1, 1, 48)     0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_1021 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# conv2d_1022 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# conv2d_1023 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1024 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# conv2d_1025 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# conv2d_1026 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# conv2d_1027 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# conv2d_1028 (Conv2D)            (None, 1, 1, 192)    9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# concatenate_140 (Concatenate)   (None, 1, 1, 1536)   0           conv2d_1021[0][0]
#                                                                  conv2d_1022[0][0]
#                                                                  conv2d_1023[0][0]
#                                                                  conv2d_1024[0][0]
#                                                                  conv2d_1025[0][0]
#                                                                  conv2d_1026[0][0]
#                                                                  conv2d_1027[0][0]
#                                                                  conv2d_1028[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 1, 1, 1536)   6144        concatenate_140[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 1, 1, 1536)   0           activation_130[0][0]
#                                                                  batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 1, 1, 1536)   0           add_52[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1536)         0           activation_132[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           15370       global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 950,290
# Trainable params: 911,122
# Non-trainable params: 39,168
# __________________________________________________________________________________________________
# None

# %%
import tensorflow as tf
import keras.backend as K


def get_flops(model):
    run_meta = tf.RunMetadata()
    opts = tf.profiler.ProfileOptionBuilder.float_operation()

    # We use the Keras session graph in the call to the profiler.
    flops = tf.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)

    return flops.total_float_ops  # Prints the "flops" of the model.


# .... Define your model here ....
print(get_flops(model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# 55535096

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/gdrive/My\ Drive/foo.txt
# Out:
# Hello Google Drive!

# %%
#TODO how to access drive / save and load files
model.save_weights('/content/gdrive/My Drive/my_model_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b5eee4969e43> in <module>()
# ----> 1 model.save_weights('/content/gdrive/My Drive/my_model_weights.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save_weights(self, filepath, overwrite)
#    1119                 return
#    1120         with h5py.File(filepath, 'w') as f:
# -> 1121             saving.save_weights_to_hdf5_group(f, self.layers)
#    1122             f.flush()
#    1123
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_weights_to_hdf5_group(f, layers)
#     570         g = f.create_group(layer.name)
#     571         symbolic_weights = layer.weights
# --> 572         weight_values = K.batch_get_value(symbolic_weights)
#     573         weight_names = []
#     574         for i, (w, val) in enumerate(zip(symbolic_weights, weight_values)):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2418     """
#    2419     if ops:
# -> 2420         return get_session().run(ops)
#    2421     else:
#    2422         return []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.save('trained_model.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f6e5f55fb02a> in <module>()
# ----> 1 model.save('trained_model.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#      95         layer_group = model_weights_group[layer.name]
#      96         symbolic_weights = layer.weights
# ---> 97         weight_values = K.batch_get_value(symbolic_weights)
#      98         weight_names = []
#      99         for i, (w, val) in enumerate(zip(symbolic_weights, weight_values)):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2418     """
#    2419     if ops:
# -> 2420         return get_session().run(ops)
#    2421     else:
#    2422         return []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
